# %%
import pandas as pd

df = pd.read_csv(
    r"C:\Users\Saran\Downloads\Lead_Filters.csv",
    encoding="latin1"
)

print(df.head())
# Out:
#   (102) Lead Filters   Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 0                  #         Name       City      State    Country   Zip Code
# 1               2402  Padma Priya        NaN        NaN      India        NaN
# 2               2401      No Name        NaN        NaN      India        NaN
# 3               2400      Krishna        NaN        NaN      India        NaN
# 4               2399  Muthu Kumar        NaN        NaN      India        NaN
#
#    Unnamed: 6 Unnamed: 7 Unnamed: 8                     Unnamed: 9  \
# 0  Lead value     Status     Source                   Created Date
# 1          ?0    Invalid  dm 24,999  173564222331-12-2024 16:20:23
# 2          ?0    Invalid  dm 24,999  173564217631-12-2024 16:19:36
# 3          ?0   Followup  dm 24,999  173564214031-12-2024 16:19:00
# 4          ?0   Followup  dm 24,999  173564210231-12-2024 16:18:22
#
#                      Unnamed: 10 Unnamed: 11     Unnamed: 12 Unnamed: 13
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2011 entries, 0 to 2010
# Data columns (total 14 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   (102) Lead Filters  2011 non-null   object
#  1   Unnamed: 1          2011 non-null   object
#  2   Unnamed: 2          1187 non-null   object
#  3   Unnamed: 3          13 non-null     object
#  4   Unnamed: 4          1553 non-null   object
#  5   Unnamed: 5          9 non-null      object
#  6   Unnamed: 6          2011 non-null   object
#  7   Unnamed: 7          2011 non-null   object
#  8   Unnamed: 8          2011 non-null   object
#  9   Unnamed: 9          2011 non-null   object
#  10  Unnamed: 10         1557 non-null   object
#  11  Unnamed: 11         2011 non-null   object
#  12  Unnamed: 12         2011 non-null   object
#  13  Unnamed: 13         909 non-null    object
# dtypes: object(14)
# memory usage: 220.1+ KB

# %%
df.isnull().any()
# Out:
# (102) Lead Filters    False
# Unnamed: 1            False
# Unnamed: 2             True
# Unnamed: 3             True
# Unnamed: 4             True
# Unnamed: 5             True
# Unnamed: 6            False
# Unnamed: 7            False
# Unnamed: 8            False
# Unnamed: 9            False
# Unnamed: 10            True
# Unnamed: 11           False
# Unnamed: 12           False
# Unnamed: 13            True
# dtype: bool

# %%
df.isnull().sum()
# Out:
# (102) Lead Filters       0
# Unnamed: 1               0
# Unnamed: 2             824
# Unnamed: 3            1998
# Unnamed: 4             458
# Unnamed: 5            2002
# Unnamed: 6               0
# Unnamed: 7               0
# Unnamed: 8               0
# Unnamed: 9               0
# Unnamed: 10            454
# Unnamed: 11              0
# Unnamed: 12              0
# Unnamed: 13           1102
# dtype: int64

# %%
df = df.iloc[1:]
df.columns = df.iloc[0]
df = df.iloc[1:].reset_index(drop=True)

# %%
df.columns
# Out:
# Index([                         '2402',                   'Padma Priya',
#                                    nan,                             nan,
#                                'India',                             nan,
#                                   '?0',                       'Invalid',
#                            'dm 24,999', '173564222331-12-2024 16:20:23',
#        '173564222331-12-2024 16:20:23',                           'Yes',
#                       'Harish Kumar K',                             nan],
#       dtype='object', name=1)

# %%
df = pd.read_csv(
    r"C:\Users\Saran\Downloads\Lead_Filters.csv",
    encoding="latin1",
    header=1
)

print(df.columns)
print(df.head())
# Out:
# Index(['#', 'Name', 'City', 'State', 'Country', 'Zip Code', 'Lead value',
#        'Status', 'Source', 'Created Date', 'Last Contact', 'Public',
#        'Assigned', 'Tags'],
#       dtype='object')
#       #         Name City State Country  Zip Code Lead value          Status  \
# 0  2402  Padma Priya  NaN   NaN   India       NaN         ?0         Invalid
# 1  2401      No Name  NaN   NaN   India       NaN         ?0         Invalid
# 2  2400      Krishna  NaN   NaN   India       NaN         ?0        Followup
# 3  2399  Muthu Kumar  NaN   NaN   India       NaN         ?0        Followup
# 4  2398  Sahabu Deen  NaN   NaN   India       NaN         ?0  Not interested
#
#       Source                   Created Date                   Last Contact  \
# 0  dm 24,999  173564222331-12-2024 16:20:23  173564222331-12-2024 16:20:23
# 1  dm 24,999  173564217631-12-2024 16:19:36  173564217631-12-2024 16:19:36
# 2  dm 24,999  173564214031-12-2024 16:19:00  173564214031-12-2024 16:19:00
# ...

# %%
print(df.shape)
print(df.columns.tolist())
# Out:
# (2010, 14)
# ['#', 'Name', 'City', 'State', 'Country', 'Zip Code', 'Lead value', 'Status', 'Source', 'Created Date', 'Last Contact', 'Public', 'Assigned', 'Tags']

# %%
df.isnull().sum()
# Out:
# #                  0
# Name               0
# City             824
# State           1998
# Country          458
# Zip Code        2002
# Lead value         0
# Status             0
# Source             0
# Created Date       0
# Last Contact     454
# Public             0
# Assigned           0
# Tags            1102
# dtype: int64

# %%
df['City'] = df['City'].fillna('Unknown')

# %%
missing = df.isnull().sum().sort_values(ascending=False)
print(missing)
# Out:
# Zip Code        2002
# State           1998
# Tags            1102
# Country          458
# Last Contact     454
# #                  0
# City               0
# Name               0
# Lead value         0
# Status             0
# Created Date       0
# Source             0
# Public             0
# Assigned           0
# dtype: int64

# %%
# Drop columns with too many missing values
df = df.drop(columns=['Zip Code', 'Tags'])

# Fill missing values
df['Country'] = df['Country'].fillna('Unknown')
df['Last Contact'] = df['Last Contact'].fillna('No Contact')
df['State'] = df['State'].fillna('unknown')

# %%
df.isnull().any()
# Out:
# #               False
# Name            False
# City            False
# State           False
# Country         False
# Lead value      False
# Status          False
# Source          False
# Created Date    False
# Last Contact    False
# Public          False
# Assigned        False
# dtype: bool

# %%
df.isnull().sum()
# Out:
# #               0
# Name            0
# City            0
# State           0
# Country         0
# Lead value      0
# Status          0
# Source          0
# Created Date    0
# Last Contact    0
# Public          0
# Assigned        0
# dtype: int64

# %%
df.columns
# Out:
# Index(['#', 'Name', 'City', 'State', 'Country', 'Lead value', 'Status',
#        'Source', 'Created Date', 'Last Contact', 'Public', 'Assigned'],
#       dtype='object')

# %%
df.to_csv("C:/Users/Saran/Downloads/cleaned_Lead_Filters.csv")
